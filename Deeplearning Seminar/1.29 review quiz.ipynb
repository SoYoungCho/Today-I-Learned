# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q1. ![image.png](attachment:image.png)

# %% [markdown]
# Q2. ![image.png](attachment:image.png)

# %% [markdown]
# Q3. 확률분포 비교시, 비교 기준이 되는 p는 동일하다. 다시 말해
#
# -$\Sigma p(x) log q(x) / p(x)$ 의 식을 풀어쓴
#
# -$\Sigma log q(x)$ - $\Sigma log p(x)$ 에서의 -$\Sigma log p(x)$는 동일하기 때문에 구해줄 필요가 없다.

# %% [markdown]
# Q4.
